# %% [markdown]
# PyPDFLoader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("../DocumentLoaders/attention.pdf")
document = loader.load()
print(document)

# %%
print(document[0])

# %%
print(document[1])
