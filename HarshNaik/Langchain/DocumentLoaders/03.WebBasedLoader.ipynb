# %% [markdown]
# WEBBASEDLOADER

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader = WebBaseLoader(web_paths = ["https://lilianweng.github.io/posts/2023-06-23-agent/"],
      bs_kwargs = dict(
        parse_only = bs4.SoupStrainer(
            class_ = ("post-content","post-content","post-header")
        )
      ))
documents =loader.load()
print(documents)

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader = WebBaseLoader(web_paths=["https://magazine.sebastianraschka.com/p/llm-research-papers-2025-list-one"],
           bs_kwargs= dict(
                     parse_only = bs4.SoupStrainer(
                       class_ = ["post-header","available-content"]
                       )
                    )
                )
documents = loader.load()
print(documents)
