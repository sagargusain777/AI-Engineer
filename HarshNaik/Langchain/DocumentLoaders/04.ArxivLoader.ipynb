# %% [markdown]
# Arxiv Loader

# %%
from langchain_community.document_loaders import ArxivLoader

loader = ArxivLoader(query='2601.04945',load_max_docs=2)
document = loader.load()
print(document)

# %%
len(document)
