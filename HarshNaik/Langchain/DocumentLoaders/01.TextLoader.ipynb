# %% [markdown]
# Text Loader in Langchain

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("speech.txt")
documents = loader.load()
print(documents)
finaldocuments = documents[0]
print(finaldocuments)
type(finaldocuments)  #langchain_core.documents.base.Document
type(documents)    #list

# %%
from langchain_community.document_loaders import TextLoader

Loader = TextLoader("speech.txt")
document = Loader.load()
final_document = document[0]
print(final_document)
type(final_document)
